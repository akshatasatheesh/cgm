# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
data = pd.read_excel('Dataset_muSORS.xlsx', sheet_name='Extended Data Fig. 2')

# %%
depth = data['Depth (um)']
intensity = data['Intensity']

# %%
if not os.path.exists('output_figures'):
    os.mkdir('output_figures')

# %%
plt.plot(depth, intensity)
plt.savefig('output_figures/depth_profile.pdf')
